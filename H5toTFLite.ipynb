# %%
# %tensorflow_version 2.1
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.1`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.

# %%
import tensorflow as tf

# %%
# %cd drive/My\ Drive/TFmodels/Gatos&Cactus/
# Out:
# /content/drive/My Drive/TFmodels/Gatos&Cactus

# %%
model = tf.keras.models.load_model('modelo_colab/modelo.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("modelo_colab/modelo.tflite", "wb").write(tflite_model)
# Out:
# 89760836
